# %%
from IPython.display import Image
Image('pandas1.jpg')

# %%
import pandas

linha_coluna={'0':['00','10','20','30','40'],
              '1':['01','11','21','31','41'],
              '2':['02','12','22','32','42'],
              '3':['03','13','23','33','43'],
              '4':['04','14','24','34','44']}

dataframe=pandas.DataFrame(linha_coluna)

# %%
dataframe
# Out:
#     0   1   2   3   4
# 0  00  01  02  03  04
# 1  10  11  12  13  14
# 2  20  21  22  23  24
# 3  30  31  32  33  34
# 4  40  41  42  43  44

# %%
dataframe[::]
# Out:
#     0   1   2   3   4
# 0  00  01  02  03  04
# 1  10  11  12  13  14
# 2  20  21  22  23  24
# 3  30  31  32  33  34
# 4  40  41  42  43  44

# %%
df1 = dataframe.astype('float64')
df1
# Out:
#       0     1     2     3     4
# 0   0.0   1.0   2.0   3.0   4.0
# 1  10.0  11.0  12.0  13.0  14.0
# 2  20.0  21.0  22.0  23.0  24.0
# 3  30.0  31.0  32.0  33.0  34.0
# 4  40.0  41.0  42.0  43.0  44.0

# %%
df2 = df1.sum()
df2
# Out:
# 0    100.0
# 1    105.0
# 2    110.0
# 3    115.0
# 4    120.0
# dtype: float64

# %%
# ordem inversa
df1[::-1]
# Out:
#       0     1     2     3     4
# 4  40.0  41.0  42.0  43.0  44.0
# 3  30.0  31.0  32.0  33.0  34.0
# 2  20.0  21.0  22.0  23.0  24.0
# 1  10.0  11.0  12.0  13.0  14.0
# 0   0.0   1.0   2.0   3.0   4.0

# %%
from IPython.display import Image
Image('pandas-different-between-loc-vs-iloc.png')

# %%
df1
# Out:
#       0     1     2     3     4
# 0   0.0   1.0   2.0   3.0   4.0
# 1  10.0  11.0  12.0  13.0  14.0
# 2  20.0  21.0  22.0  23.0  24.0
# 3  30.0  31.0  32.0  33.0  34.0
# 4  40.0  41.0  42.0  43.0  44.0

# %%
# por coluna 
print(df1.loc[:,'3':'4'])
# Out:
#       3     4
# 0   3.0   4.0
# 1  13.0  14.0
# 2  23.0  24.0
# 3  33.0  34.0
# 4  43.0  44.0

# %%
# por coluna
print(dataframe.loc[:,['1','2','3']])
# Out:
#     1   2   3
# 0  01  02  03
# 1  11  12  13
# 2  21  22  23
# 3  31  32  33
# 4  41  42  43

# %%
print(dataframe.loc[:,['3']])
# Out:
#     3
# 0  03
# 1  13
# 2  23
# 3  33
# 4  43

# %%
df1
# Out:
#       0     1     2     3     4
# 0   0.0   1.0   2.0   3.0   4.0
# 1  10.0  11.0  12.0  13.0  14.0
# 2  20.0  21.0  22.0  23.0  24.0
# 3  30.0  31.0  32.0  33.0  34.0
# 4  40.0  41.0  42.0  43.0  44.0

# %%
(df1.loc[:,['3']])
# Out:
#       3
# 0   3.0
# 1  13.0
# 2  23.0
# 3  33.0
# 4  43.0

# %%
df3 = (df1.loc[:,['3']]).mean()
df3
# Out:
# 3    23.0
# dtype: float64

# %%
df1
# Out:
#       0     1     2     3     4
# 0   0.0   1.0   2.0   3.0   4.0
# 1  10.0  11.0  12.0  13.0  14.0
# 2  20.0  21.0  22.0  23.0  24.0
# 3  30.0  31.0  32.0  33.0  34.0
# 4  40.0  41.0  42.0  43.0  44.0

# %%
# por linha e coluna 
print(df1.loc[1,'3'])
# Out:
# 13.0

# %%
# por linha
print(df1.loc[2,:])
# Out:
# 0    20.0
# 1    21.0
# 2    22.0
# 3    23.0
# 4    24.0
# Name: 2, dtype: float64

# %%
from IPython.display import Image
Image('pandas-different-between-loc-vs-iloc.png')

# %%
# por linha - fatiamento
print(df1.loc[3:])
# Out:
#       0     1     2     3     4
# 3  30.0  31.0  32.0  33.0  34.0
# 4  40.0  41.0  42.0  43.0  44.0

# %%
df1
# Out:
#       0     1     2     3     4
# 0   0.0   1.0   2.0   3.0   4.0
# 1  10.0  11.0  12.0  13.0  14.0
# 2  20.0  21.0  22.0  23.0  24.0
# 3  30.0  31.0  32.0  33.0  34.0
# 4  40.0  41.0  42.0  43.0  44.0

# %%
# por linha e coluna - fatiamento
print(df1.loc[3:,['3','4']])
# Out:
#       3     4
# 3  33.0  34.0
# 4  43.0  44.0

# %%
df1
# Out:
#       0     1     2     3     4
# 0   0.0   1.0   2.0   3.0   4.0
# 1  10.0  11.0  12.0  13.0  14.0
# 2  20.0  21.0  22.0  23.0  24.0
# 3  30.0  31.0  32.0  33.0  34.0
# 4  40.0  41.0  42.0  43.0  44.0

# %%
# por linha e coluna com step 
print(df1.loc[2::2,'1'::2])
# Out:
#       1     3
# 2  21.0  23.0
# 4  41.0  43.0

# %%
from IPython.display import Image
Image('pandas-different-between-loc-vs-iloc-2.png')

# %%
print(df1.iloc[2:])
# Out:
#       0     1     2     3     4
# 2  20.0  21.0  22.0  23.0  24.0
# 3  30.0  31.0  32.0  33.0  34.0
# 4  40.0  41.0  42.0  43.0  44.0

# %%
df1
# Out:
#       0     1     2     3     4
# 0   0.0   1.0   2.0   3.0   4.0
# 1  10.0  11.0  12.0  13.0  14.0
# 2  20.0  21.0  22.0  23.0  24.0
# 3  30.0  31.0  32.0  33.0  34.0
# 4  40.0  41.0  42.0  43.0  44.0

# %%
print(df1.iloc[2,1:3])
# Out:
# 1    21.0
# 2    22.0
# Name: 2, dtype: float64
