# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
print(matplotlib.__version__)
print(np.__version__)
print(pd.__version__)
# Out:
# 3.7.2
# 1.24.4
# 2.0.3

# %%
acucares = pd.read_excel('acucares_min_max.xlsx')

x = acucares['fabricante']
y = acucares['min_acucares']

plt.title("Açucares")
plt.xlabel("Fabricante")
plt.ylabel("Mínimo")
plt.grid()
plt.bar(x,y)
plt.show()
#acucares
